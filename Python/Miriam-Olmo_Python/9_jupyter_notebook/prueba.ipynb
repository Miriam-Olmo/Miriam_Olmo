# %%
import pandas as pd

# %% [markdown]
# # titulo del notebook
#
# este texto seria una posible explicacion al codigo

# %%
numero_a = 10
numero_b = 5

def sumar(a,b):
    return a + b

resultado = sumar(numero_a, numero_b)

# %% [markdown]
# # nuestra explicacion continuaria
#
# aqui pondriamos mas cosas. me gustaria sacar el doble del resultado obtenido

# %%
doble = resultado * 2

print(doble)
# Out:
# 30
