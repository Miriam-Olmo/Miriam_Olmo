# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "nombre":      ["Ana", "Luis", "Eva", "Carlos", "Marta", "Pedro", "Laura", "Tomás"],
    "departamento":["IT", "Ventas", "IT", "RRHH", "Ventas", "IT", "RRHH", "Ventas"],
    "edad":        [23, 31, 28, 45, 22, 'none', 35, 27],
    "salario":     [28000, 42000, 35000, None, 24000, 55000, 48000, 31000],
    "activo":      [True, True, False, True, True, True, False, True],
    "fecha_alta":  pd.to_datetime(["2022-01-10", "2019-06-15", "2021-03-20",
                                   "2015-11-01", "2023-02-28", "2017-08-12",
                                   "2020-04-05", "2021-09-18"])
})

print(df)
print(df.info())
print(df.describe())
# Out:
#    nombre departamento  edad  salario  activo fecha_alta
# 0     Ana           IT    23  28000.0    True 2022-01-10
# 1    Luis       Ventas    31  42000.0    True 2019-06-15
# 2     Eva           IT    28  35000.0   False 2021-03-20
# 3  Carlos         RRHH    45      NaN    True 2015-11-01
# 4   Marta       Ventas    22  24000.0    True 2023-02-28
# 5   Pedro           IT  none  55000.0    True 2017-08-12
# 6   Laura         RRHH    35  48000.0   False 2020-04-05
# 7   Tomás       Ventas    27  31000.0    True 2021-09-18
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   nombre        8 non-null      str
#  1   departamento  8 non-null      str
#  2   edad          8 non-null      object
#  3   salario       7 non-null      float64
#  4   activo        8 non-null      bool
#  5   fecha_alta    8 non-null      datetime64[us]
# dtypes: bool(1), datetime64[us](1), float64(1), object(1), str(2)
# memory usage: 460.0+ bytes
# None
#             salario           fecha_alta
# count      7.000000                    8
# mean   37571.428571  2020-02-28 03:00:00
# min    24000.000000  2015-11-01 00:00:00
# 25%    29500.000000  2018-12-29 00:00:00
# 50%    35000.000000  2020-09-26 12:00:00
# 75%    45000.000000  2021-10-16 12:00:00
# max    55000.000000  2023-02-28 00:00:00
# std    11237.691680                  NaN

# %% [markdown]
# ## exploracion de columnas por categoria: value_count, unique, nunique

# %%
## value_counts: repeticion de cada valor . departamentos
print(df['departamento'].value_counts())
## por porcentaje de departamento
print(df['departamento'].value_counts(normalize=True) * 100)
# Out:
# departamento
# IT        3
# Ventas    3
# RRHH      2
# Name: count, dtype: int64
# departamento
# IT        37.5
# Ventas    37.5
# RRHH      25.0
# Name: proportion, dtype: float64

# %%
# lista de valores unicos por departamento
print(df['departamento'].unique())

# nunique: numero de valores unicos por columna
print(df.nunique())
# Out:
# <StringArray>
# ['IT', 'Ventas', 'RRHH']
# Length: 3, dtype: str
# nombre          8
# departamento    3
# edad            8
# salario         7
# activo          2
# fecha_alta      8
# dtype: int64

# %% [markdown]
# ## valores nulos: primera deteccion

# %%
print(df.isnull())

print(df.isna())

print('total nulos')
print(df['salario'].isnull().sum())
# Out:
#    nombre  departamento   edad  salario  activo  fecha_alta
# 0   False         False  False    False   False       False
# 1   False         False  False    False   False       False
# 2   False         False  False    False   False       False
# 3   False         False  False     True   False       False
# 4   False         False  False    False   False       False
# 5   False         False  False    False   False       False
# 6   False         False  False    False   False       False
# 7   False         False  False    False   False       False
#    nombre  departamento   edad  salario  activo  fecha_alta
# 0   False         False  False    False   False       False
# 1   False         False  False    False   False       False
# 2   False         False  False    False   False       False
# 3   False         False  False     True   False       False
# 4   False         False  False    False   False       False
# 5   False         False  False    False   False       False
# 6   False         False  False    False   False       False
# 7   False         False  False    False   False       False
# total nulos
# 1

# %% [markdown]
# ---
# **Resumen — checklist de exploración inicial:**
# 1. `df.shape` → dimensiones
# 2. `df.head()` / `df.tail()` → ver los datos
# 3. `df.info()` → tipos y nulos de un vistazo
# 4. `df.describe()` → estadísticas numéricas
# 5. `df[col].value_counts()` → distribución de categóricas
# 6. `df.isnull().sum()` → conteo de nulos
