# %%
import pandas as pd

# %% [markdown]
# # Titulo del notebook
#
# Este texto sería una posible explicación al código

# %%
numero_a = 10
numero_b = 5

def sumar(a,b):
    return a + b

resultado = sumar(numero_a, numero_b)

# %% [markdown]
# ### Nuestra explicación continuaria
#
# Aquí pondriamos mas cosas. Me gustaría sacar el doble del resultado obtenido

# %%
doble = resultado * 2

print(doble)
# Out:
# 30

# %%
lista = [1,2,3,4,5]
df = pd.DataFrame(lista)
print(df)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5
